# %% [markdown]
# <a href="https://colab.research.google.com/github/kmeng01/rome/blob/main/notebooks/causal_trace.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" align="left"/></a>&nbsp;or in a local notebook.

# %%
# %%bash
# !(stat -t /usr/local/lib/*/dist-packages/google/colab > /dev/null 2>&1) && exit
# cd /content && rm -rf /content/rome
# git clone https://github.com/kmeng01/rome rome > install.log 2>&1
# pip install -r /content/rome/scripts/colab_reqs/rome.txt >> install.log 2>&1
# pip install --upgrade google-cloud-storage >> install.log 2>&1

# %%
IS_COLAB = False
try:
    import google.colab, torch, os

    IS_COLAB = True
    os.chdir("/content/rome")
    if not torch.cuda.is_available():
        raise Exception("Change runtime type to include a GPU.")
except ModuleNotFoundError as _:
    pass

# %% [markdown]
# ## Causal Tracing
#
# A demonstration of the double-intervention causal tracing method.
#
# The strategy used by causal tracing is to understand important
# states within a transfomer by doing two interventions simultaneously:
#
# 1. Corrupt a subset of the input.  In our paper, we corrupt the subject tokens
#    to frustrate the ability of the transformer to accurately complete factual
#    prompts about the subject.
# 2. Restore a subset of the internal hidden states.  In our paper, we scan
#    hidden states at all layers and all tokens, searching for individual states
#    that carry the necessary information for the transformer to recover its
#    capability to complete the factual prompt.
#
# The traces of decisive states can be shown on a heatmap.  This notebook
# demonstrates the code for conducting causal traces and creating these heatmaps.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# The `experiments.causal_trace` module contains a set of functions for running causal traces.
#
# In this notebook, we reproduce, demonstrate and discuss the interesting functions.
#
# We begin by importing several utility functions that deal with tokens and transformer models.

# %%
import os, re, json
import torch, numpy
from collections import defaultdict
from util import nethook
from util.globals import DATA_DIR
from experiments.causal_trace import (
    ModelAndTokenizer,
    layername,
    guess_subject,
    plot_trace_heatmap,
)
from experiments.causal_trace import (
    make_inputs,
    decode_tokens,
    find_token_range,
    predict_token,
    predict_from_input,
    collect_embedding_std,
)
from dsets import KnownsDataset

os.environ["CUDA_VISIBLE_DEVICES"] = "3"

torch.set_grad_enabled(False)

# %%
torch.cuda.empty_cache()

# %% [markdown]
# Now we load a model and tokenizer, and show that it can complete a couple factual statements correctly.

# %%
model_name = "gpt2-medium"  # or "EleutherAI/gpt-j-6B" or "EleutherAI/gpt-neox-20b"
mt = ModelAndTokenizer(
    model_name,
    low_cpu_mem_usage=IS_COLAB,
    torch_dtype=(torch.float16 if "20b" in model_name else None),
)

# %%
predict_token(
    mt,
    ["Robert DeNiro is an", "The CN Tower is in the city of"],
    return_p=True,
)
# Out:
# ([' an', ' Toronto'], tensor([0.1392, 0.1222], device='cuda:0'))

# %%
knowns = KnownsDataset(DATA_DIR)  # Dataset of known facts
knowns[0:2]
# Out:
# Loaded dataset with 1209 elements
# [{'known_id': 0,
#   'subject': 'Vinson Massif',
#   'attribute': 'Antarctica',
#   'template': '{} is located in the continent',
#   'prediction': ' of Antarctica. It is the largest of the three',
#   'prompt': 'Vinson Massif is located in the continent of',
#   'relation_id': 'P30'},
#  {'known_id': 1,
#   'subject': 'Beats Music',
#   'attribute': 'Apple',
#   'template': '{} is owned by',
#   'prediction': ' Apple, which is also the owner of Beats Electronics',
#   'prompt': 'Beats Music is owned by',
#   'relation_id': 'P127'}]

# %% [markdown]
# To obfuscate the subject during Causal Tracing, we use noise sampled from a zero-centered spherical Gaussian, whose stddev is 3 times the $\sigma$ stddev the model's embeddings. Let's compute that value.

# %%
knowns = KnownsDataset(DATA_DIR)  # Dataset of known facts
noise_level = 3 * collect_embedding_std(mt, [k["subject"] for k in knowns])
print(f"Using noise level {noise_level}")
# Out:
# Loaded dataset with 1209 elements
# Using noise level 0.3257756531238556

# %% [markdown]
# ## Tracing a single location
#
# The core intervention in causal tracing is captured in this function:
#
# `trace_with_patch` a single causal trace.
#
# It enables running a batch of inferences with two interventions.
#
#   1. Random noise can be added to corrupt the inputs of some of the batch.
#   2. At any point, clean non-noised state can be copied over from an
#      uncorrupted batch member to other batch members.
#
# The convention used by this function is that the zeroth element of the
# batch is the uncorrupted run, and the subsequent elements of the batch
# are the corrupted runs.  The argument tokens_to_mix specifies an
# be corrupted by adding Gaussian noise to the embedding for the batch
# inputs other than the first element in the batch.  Alternately,
# subsequent runs could be corrupted by simply providing different
# input tokens via the passed input batch.
#
# To ensure that corrupted behavior is representative, in practice, we
# will actually run several (ten) corrupted runs in the same batch,
# each with its own sample of noise.
#
# Then when running, a specified set of hidden states will be uncorrupted
# by restoring their values to the same vector that they had in the
# zeroth uncorrupted run.  This set of hidden states is listed in
# states_to_patch, by listing [(token_index, layername), ...] pairs.
# To trace the effect of just a single state, this can be just a single
# token/layer pair.  To trace the effect of restoring a set of states,
# any number of token indices and layers can be listed.
#
# Note that this function is also in experiments.causal_trace; the code
# is shown here to show the logic.

# %%
#pass in the model, the input containing 10 copies of both the tokens and the attention, pass in the range for the subject tokens, pass in the answer, pass in noise

def trace_with_patch(
    model,  # The model
    inp,  # A set of inputs
    states_to_patch,  # A list of (token index, layername) triples to restore
    answers_t,  # Answer probabilities to collect
    tokens_to_mix,  # Range of tokens to corrupt (begin, end)
    noise=0.1,  # Level of noise to add
    trace_layers=None,  # List of traced outputs to return
):
    prng = numpy.random.RandomState(1)  # For reproducibility, use pseudorandom noise
    patch_spec = defaultdict(list)
    for t, l in states_to_patch:
        patch_spec[l].append(t)
    embed_layername = layername(model, 0, "embed")

    def untuple(x):
        return x[0] if isinstance(x, tuple) else x

    # Define the model-patching rule.
    def patch_rep(x, layer):
        if layer == embed_layername:
            # If requested, we corrupt a range of token embeddings on batch items x[1:]
            if tokens_to_mix is not None:
                b, e = tokens_to_mix
                x[1:, b:e] += noise * torch.from_numpy(
                    prng.randn(x.shape[0] - 1, e - b, x.shape[2])
                ).to(x.device)
            return x
        if layer not in patch_spec:
            return x
        # If this layer is in the patch_spec, restore the uncorrupted hidden state
        # for selected tokens.
        h = untuple(x)
        for t in patch_spec[layer]:
            h[1:, t] = h[0, t]
        return x

    # With the patching rules defined, run the patched model in inference.
    additional_layers = [] if trace_layers is None else trace_layers
    with torch.no_grad(), nethook.TraceDict(
        model,
        [embed_layername] + list(patch_spec.keys()) + additional_layers,
        edit_output=patch_rep,
    ) as td:
        outputs_exp = model(**inp)

        

    # We report softmax probabilities for the answers_t token predictions of interest.
    probs = torch.softmax(outputs_exp.logits[1:, -1, :], dim=1).mean(dim=0)[answers_t]

    # If tracing all layers, collect all activations together to return.
    if trace_layers is not None:
        all_traced = torch.stack(
            [untuple(td[layer].output).detach().cpu() for layer in trace_layers], dim=2
        )
        return probs, all_traced

    return probs

# %%
"thespaceneedle".index("space")
# Out:
# 3

# %% [markdown]
# ## Scanning all locations
#
# A causal flow heatmap is created by repeating `trace_with_patch` at every individual hidden state, and measuring the impact of restoring state at each location.
#
# The `calculate_hidden_flow` function does this loop.  It handles both the case of restoring a single hidden state, and also restoring MLP or attention states.  Because MLP and attention make small residual contributions, to observe a causal effect in those cases, we need to restore several layers of contributions at once, which is done by `trace_important_window`.

# %%
def calculate_hidden_flow(
    mt, prompt, target, subject, samples=10, noise=0.1, window=10, kind=None
):
    """
    Runs causal tracing over every token/layer combination in the network
    and returns a dictionary numerically summarizing the results.
    """
    inp = make_inputs(mt.tokenizer, [prompt] * (samples + 1))
    #create 11 copies of tokens from our prompt sentence

    '''with torch.no_grad():
        answer_t, base_score = [d[0] for d in predict_from_input(mt.model, inp)]

        #answer_t is what the model deems to be the highest probability label
        #base_score is the assigned probability
    

    [answer] = decode_tokens(mt.tokenizer, [answer_t])

    print(answer_t)'''

    answer = target

    answer_t = mt.tokenizer.convert_tokens_to_ids(target)

    #answer is what the model fills the blank in with

    #pass in a tokenizer, the tokenized ids, and the subject
    e_range = find_token_range(mt.tokenizer, inp["input_ids"][0], subject)

    #e_range contains [subject token start index, subject token end index], we will obfuscate/corrupt the tokens in this range


    #pass in the model, the input containing 10 copies of both the tokens and the attention, pass in the range for the subject tokens, pass in the answer, pass in noise
    low_score = trace_with_patch(
        mt.model, inp, [], answer_t, e_range, noise=noise
    ).item()

    
    if not kind:
        differences = trace_important_states(
            mt.model, mt.num_layers, inp, e_range, answer_t, noise=noise
        )
    else:
        differences = trace_important_window(
            mt.model,
            mt.num_layers,
            inp,
            e_range,
            answer_t,
            noise=noise,
            window=window,
            kind=kind,
        )
    differences = differences.detach().cpu()
    return dict(
        scores=differences,
        low_score=low_score,
        #high_score=base_score,
        input_ids=inp["input_ids"][0],
        input_tokens=decode_tokens(mt.tokenizer, inp["input_ids"][0]),
        subject_range=e_range,
        answer=answer,
        window=window,
        kind=kind or "",
    )


def trace_important_states(model, num_layers, inp, e_range, answer_t, noise=0.1):
    ntoks = inp["input_ids"].shape[1]
    table = []
    for tnum in range(ntoks):
        row = []
        for layer in range(0, num_layers):
            r = trace_with_patch(
                model,
                inp,
                [(tnum, layername(model, layer))],
                answer_t,
                tokens_to_mix=e_range,
                noise=noise,
            )
            row.append(r)
        table.append(torch.stack(row))
    return torch.stack(table)


def trace_important_window(
    model, num_layers, inp, e_range, answer_t, kind, window=10, noise=0.1
):
    ntoks = inp["input_ids"].shape[1]
    table = []
    for tnum in range(ntoks):
        row = []
        for layer in range(0, num_layers):
            layerlist = [
                (tnum, layername(model, L, kind))
                for L in range(
                    max(0, layer - window // 2), min(num_layers, layer - (-window // 2))
                )
            ]
            r = trace_with_patch(
                model, inp, layerlist, answer_t, tokens_to_mix=e_range, noise=noise
            )
            row.append(r)
        table.append(torch.stack(row))
    return torch.stack(table)

# %% [markdown]
# ## Plotting the results
#
# The `plot_trace_heatmap` function draws the data on a heatmap.  That function is not shown here; it is in `experiments.causal_trace`.

# %%
def plot_hidden_flow(
    mt,
    prompt,
    target,
    subject=None,
    samples=10,
    noise=0.1,
    window=10,
    kind=None,
    modelname=None,
    savepdf=None,
):
    if subject is None:
        subject = guess_subject(prompt)
    result = calculate_hidden_flow(
        mt, prompt, target, subject, samples=samples, noise=noise, window=window, kind=kind
    )

    plot_trace_heatmap(result, savepdf, modelname=modelname)
    return result["scores"]# - result["low_score"]



def plot_all_flow(mt, prompt, target, subject=None, noise=0.1, modelname=None):
    values_dict = {}
    for kind in [None, "mlp", "attn"]:
        values = plot_hidden_flow(
            mt, prompt, target, subject, modelname=modelname, noise=noise, kind=kind
        )

        values_dict[kind] = values
    return values_dict

# %% [markdown]
# ## Calculating the Results, No Plotting

# %%
def run_hidden_flow(
    mt,
    prompt,
    target,
    subject=None,
    samples=10,
    noise=0.1,
    window=10,
    kind=None,
    modelname=None,
    savepdf=None,
):
    if subject is None:
        subject = guess_subject(prompt)
    result = calculate_hidden_flow(
        mt, prompt, target, subject, samples=samples, noise=noise, window=window, kind=kind
    )
    plot_trace_heatmap(result, savepdf, modelname=modelname)
    return result["scores"]# - result["low_score"]



def run_all_flow(mt, prompt, target, subject=None, noise=0.1, modelname=None):
    values_dict = {}
    for kind in [None, "mlp", "attn"]:
        values = run_hidden_flow(
            mt, prompt, target, subject, modelname=modelname, noise=noise, kind=kind
        )

        values_dict[kind] = values
    return values_dict

# %% [markdown]
# The following prompt can be changed to any factual statement to trace.

# %%
values_dict = plot_all_flow(mt, "Many actresses that thought about Alice healed", target = "themselves", subject="Many actresses", noise=noise_level)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 values_dict = plot_all_flow(mt, "Many actresses that thought about Alice healed", target = "themselves", subject="Many actresses", noise=noise_level)
#
# Cell In[46], line 27, in plot_all_flow(mt, prompt, target, subject, noise, modelname)
#      25 values_dict = {}
#      26 for kind in [None, "mlp", "attn"]:
# ---> 27     values = plot_hidden_flow(
#      28         mt, prompt, target, subject, modelname=modelname, noise=noise, kind=kind
#      29     )
#      31     values_dict[kind] = values
#      32 return values_dict
#
# Cell In[46], line 15, in plot_hidden_flow(mt, prompt, target, subject, samples, noise, window, kind, modelname, savepdf)
#      13 if subject is None:
#      14     subject = guess_subject(prompt)
# ---> 15 result = calculate_hidden_flow(
#      16     mt, prompt, target, subject, samples=samples, noise=noise, window=window, kind=kind
#      17 )
#      19 plot_trace_heatmap(result, savepdf, modelname=modelname)
#      20 return result["scores"]
#
# Cell In[45], line 56, in calculate_hidden_flow(mt, prompt, target, subject, samples, noise, window, kind)
#      45     differences = trace_important_window(
#      46         mt.model,
#      47         mt.num_layers,
#    (...)
#      53         kind=kind,
#      54     )
#      55 differences = differences.detach().cpu()
# ---> 56 return dict(
#      57     scores=differences,
#      58     low_score=low_score,
#      59     #high_score=base_score,
#      60     input_ids=inp["input_ids"][0],
#      61     input_tokens=decode_tokens(mt.tokenizer, inp["input_ids"][0]),
#      62     subject_range=e_range,
#      63     answer=answer,
#      64     window=window,
#      65     kind=kind or "",
#      66 )
#
# TypeError: 'dict' object is not callable

# %% [markdown]
# Here we trace a few more factual statements from a file of test cases.

# %%
import json

with open('./data/principle_A_c_command.jsonl', 'r') as json_file:
    json_list = list(json_file)

sentences_list = []


for instance in json_list:
    sentence = json.loads(instance)
    if len(sentence['sentence_good'].split()) == 9:
        dict ={}
        dict["prefix"] = sentence['one_prefix_prefix']
        dict["good_word"] = sentence['one_prefix_word_good']
        dict["bad_word"] = sentence['one_prefix_word_bad']
        dict["subject"] = ' '.join(sentence['one_prefix_prefix'].split()[:2])
        sentences_list.append(dict)
# Out:
# (334,
#  [{'prefix': 'A guy that has seen the wheelbarrow notices',
#    'good_word': 'himself',
#    'bad_word': 'itself',
#    'subject': 'A guy'},
#   {'prefix': 'The children that were complaining about Gregory hated',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'The children'},
#   {'prefix': 'The hospitals that talk to Ann talked to',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The hospitals'},
#   {'prefix': 'Many skirts that stun some waitress are boring',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Many skirts'},
#   {'prefix': "This lady who is healing Charles wasn't hiding",
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'This lady'},
#   {'prefix': 'These doctors who do leave Melissa fled from',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'These doctors'},
#   {'prefix': "These ladies that hadn't forgotten Victoria fled from",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'These ladies'},
#   {'prefix': 'Some hill that could distract Barbara is alarming',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Some hill'},
#   {'prefix': "The dancers who haven't shocked Candice aren't appreciating",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The dancers'},
#   {'prefix': "A legislature that wouldn't criticize Patrick hasn't helped",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'A legislature'},
#   {'prefix': "A guy who hasn't annoyed Laura argued about",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'A guy'},
#   {'prefix': "A cat that hasn't impressed Joseph couldn't distract",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'A cat'},
#   {'prefix': 'That plane that was scaring Wendy has disgusted',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'That plane'},
#   {'prefix': 'Some boy that disturbed Jill could argue about',
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'Some boy'},
#   {'prefix': 'These pies that were embarrassing Jennifer are annoying',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'These pies'},
#   {'prefix': 'The book that is disgusting dancers would irritate',
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'The book'},
#   {'prefix': "The men who weren't confusing Valerie were kissing",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The men'},
#   {'prefix': "Some guests who didn't discover Melissa were visiting",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Some guests'},
#   {'prefix': "Some dancer who isn't admiring mushrooms thinks about",
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'Some dancer'},
#   {'prefix': "These actors who think about Russell won't remember",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'These actors'},
#   {'prefix': 'This book that hurt Kirsten has disagreed with',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'This book'},
#   {'prefix': "These adults that won't listen to Janice impressed",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'These adults'},
#   {'prefix': "Every government that boasted about Amanda wasn't embarrassing",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Every government'},
#   {'prefix': 'Some association that would astound Gregory had scared',
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Some association'},
#   {'prefix': 'The customers that descend every hill can praise',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'The customers'},
#   {'prefix': 'That woman who had noticed John fled from',
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'That woman'},
#   {'prefix': "These guests that haven't discovered Caroline had seen",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'These guests'},
#   {'prefix': "Every girl that hadn't disgusted Travis can't approach",
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'Every girl'},
#   {'prefix': "These doctors that didn't flee from Michael visited",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'These doctors'},
#   {'prefix': 'Those students that looked like this print fired',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Those students'},
#   {'prefix': "That woman that hated Scott hadn't talked about",
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'That woman'},
#   {'prefix': 'Some women that would approach Pamela had cured',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Some women'},
#   {'prefix': 'This committee that is referencing Gina works with',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'This committee'},
#   {'prefix': "That fish that astounded this actress hadn't scared",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'That fish'},
#   {'prefix': 'That lady that was examining the movies remembers',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'That lady'},
#   {'prefix': "Most boys who have confused Kristin hadn't concealed",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Most boys'},
#   {'prefix': 'The customers who distracts the guy would investigate',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'The customers'},
#   {'prefix': "Most women that passed the hill won't conceal",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Most women'},
#   {'prefix': 'The organization that has disliked many books insults',
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'The organization'},
#   {'prefix': "Those fish that are embarrassing Catherine aren't disgusting",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Those fish'},
#   {'prefix': "Some companies that were hurting David don't criticize",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Some companies'},
#   {'prefix': "This unicycle that shouldn't hurt Suzanne will disturb",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'This unicycle'},
#   {'prefix': 'That waitress who talked about many malls observed',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'That waitress'},
#   {'prefix': "All teenagers that wouldn't sell that vase discovered",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'All teenagers'},
#   {'prefix': "People who weren't discussing Laurie didn't sound like",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'People who'},
#   {'prefix': "Some teenagers that haven't confused Eva can reveal",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Some teenagers'},
#   {'prefix': "This slope that should stun Lori isn't astounding",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'This slope'},
#   {'prefix': 'Some essay that hurt Peter has sounded like',
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Some essay'},
#   {'prefix': 'Some peppers that might alarm Lissa had disturbed',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Some peppers'},
#   {'prefix': "The lamp that isn't disgusting James can't worry",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'The lamp'},
#   {'prefix': "Every school that isn't discussing Marla had distracted",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Every school'},
#   {'prefix': "The pedestrians who referenced Candice haven't complained about",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The pedestrians'},
#   {'prefix': 'These doctors that ascend a hill had discovered',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'These doctors'},
#   {'prefix': "Some car that will irritate Mark hadn't embarrassed",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Some car'},
#   {'prefix': "Some boy who concealed an actress isn't describing",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'Some boy'},
#   {'prefix': 'That girl who cured girls does complain about',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'That girl'},
#   {'prefix': 'A woman that has most photographs disagrees with',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'A woman'},
#   {'prefix': 'Those students that should aggravate Paula did cure',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Those students'},
#   {'prefix': 'The legislatures that should praise Victoria worked with',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The legislatures'},
#   {'prefix': 'A museum that talks about Katherine talks about',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'A museum'},
#   {'prefix': "Many sketches that aren't boring Jill had hurt",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Many sketches'},
#   {'prefix': 'That grocery store that hurt Alice should aggravate',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'That grocery'},
#   {'prefix': "Some university that will distract Teresa wasn't helping",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Some university'},
#   {'prefix': "That actress who wouldn't take this screen questions",
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'That actress'},
#   {'prefix': "Every man that isn't approaching Kirsten is attacking",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'Every man'},
#   {'prefix': 'This dancer who is curing some patients criticizes',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'This dancer'},
#   {'prefix': "Some shirt that hadn't disgusted Kimberley should worry",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Some shirt'},
#   {'prefix': 'Those waitresses who clean some face have revealed',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Those waitresses'},
#   {'prefix': 'The glass that looked like many photographs bothered',
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'The glass'},
#   {'prefix': "Every company that hadn't appreciated Becky can hire",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Every company'},
#   {'prefix': "Many computers that won't disturb Becky can astound",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Many computers'},
#   {'prefix': 'Some lady that was exiting a restaurant leaves',
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'Some lady'},
#   {'prefix': 'Some mouths that would upset Florence did astound',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Some mouths'},
#   {'prefix': "Some nose that worries these patients hasn't embarrassed",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'Some nose'},
#   {'prefix': "All students that research Harvard University won't question",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'All students'},
#   {'prefix': "A boy that descends some steps doesn't attack",
#    'good_word': 'himself',
#    'bad_word': 'themselves',
#    'subject': 'A boy'},
#   {'prefix': 'Some universities that alarmed Carolyn have talked about',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Some universities'},
#   {'prefix': "This movie that hasn't impressed Meredith might aggravate",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'This movie'},
#   {'prefix': "Every scarf that had bored Benjamin wasn't boring",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Every scarf'},
#   {'prefix': "Most legislatures that aren't insulting Catherine aren't discussing",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Most legislatures'},
#   {'prefix': "The skateboard that didn't stun Gregory has astounded",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'The skateboard'},
#   {'prefix': "An actress who upset all drivers wasn't observing",
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'An actress'},
#   {'prefix': "An essay that won't worry Tiffany should distract",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'An essay'},
#   {'prefix': 'Most people who had attacked Deanna have disgusted',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Most people'},
#   {'prefix': "Many pedestrians that hadn't hurt Lisa aren't finding",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Many pedestrians'},
#   {'prefix': 'Many cashiers who can heal Guy sounded like',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Many cashiers'},
#   {'prefix': "Some horse that hasn't confused these students impressed",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'Some horse'},
#   {'prefix': "A scarf that has embarrassed Carolyn wasn't disgusting",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'A scarf'},
#   {'prefix': "Most waitresses who weren't concealing John have approached",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Most waitresses'},
#   {'prefix': "Dancers who hadn't concealed some hospital were discovering",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Dancers who'},
#   {'prefix': "Many museums that work with Mitchell couldn't help",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Many museums'},
#   {'prefix': "Children that aren't irritating David might flee from",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Children that'},
#   {'prefix': "That actress that won't discover that plate watches",
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'That actress'},
#   {'prefix': "The doors that haven't scared Amy wouldn't distract",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The doors'},
#   {'prefix': "Teachers who brought that car wouldn't disagree with",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Teachers who'},
#   {'prefix': 'This mountain that would distract Heidi can stun',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'This mountain'},
#   {'prefix': "Most women who didn't disturb Stacey are investigating",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Most women'},
#   {'prefix': "Some waitress that hadn't cured Daniel flees from",
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'Some waitress'},
#   {'prefix': 'Most girls that listen to Christopher have visited',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Most girls'},
#   {'prefix': 'Every high school that annoys Emily does impress',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Every high'},
#   {'prefix': 'The plates that have irritated Victoria were alarming',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The plates'},
#   {'prefix': "All associations that aren't boring Peter weren't discussing",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'All associations'},
#   {'prefix': "Every organization that is boring Bill wouldn't fire",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Every organization'},
#   {'prefix': "All waitresses who weren't hurting Jason might discover",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'All waitresses'},
#   {'prefix': 'Most customers who are impressing Laurie have found',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Most customers'},
#   {'prefix': "Some cars that embarrassed this boy aren't scaring",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Some cars'},
#   {'prefix': 'Some cats that resemble that painting had impressed',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Some cats'},
#   {'prefix': 'The lady who has impressed Homer had discussed',
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'The lady'},
#   {'prefix': "These cakes that don't aggravate Ruth do scare",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'These cakes'},
#   {'prefix': 'Some man who had bought every fork referenced',
#    'good_word': 'himself',
#    'bad_word': 'itself',
#    'subject': 'Some man'},
#   {'prefix': 'Every museum that helped a man could hate',
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Every museum'},
#   {'prefix': "A museum that has astounded Eva didn't hate",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'A museum'},
#   {'prefix': "This rug that hadn't stunned the doctors embarrassed",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'This rug'},
#   {'prefix': "All guests who could reveal Gerald haven't observed",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'All guests'},
#   {'prefix': "Some casserole that resembled the photographs can't disgust",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'Some casserole'},
#   {'prefix': "All pedestrians that do embarrass Christine weren't revealing",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All pedestrians'},
#   {'prefix': 'Some bicycle that looks like most sketches worried',
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'Some bicycle'},
#   {'prefix': "Some committee that hasn't remembered Kimberley isn't criticizing",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Some committee'},
#   {'prefix': 'Every waitress that exits a cafe escapes from',
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'Every waitress'},
#   {'prefix': 'The dancer that embarrassed this committee thinks about',
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'The dancer'},
#   {'prefix': "These people who hired Wayne don't complain about",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'These people'},
#   {'prefix': "All plates that were upsetting Derek shouldn't bore",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'All plates'},
#   {'prefix': "That guy who wasn't describing most guys describes",
#    'good_word': 'himself',
#    'bad_word': 'themselves',
#    'subject': 'That guy'},
#   {'prefix': "All stairs that haven't impressed Peter do stun",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'All stairs'},
#   {'prefix': "Every river that didn't scare April had annoyed",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Every river'},
#   {'prefix': 'The car that did resemble some pictures astounded',
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'The car'},
#   {'prefix': "Some bikes that aren't scaring Sherry aren't worrying",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Some bikes'},
#   {'prefix': "Some man that is hiding Dana hasn't described",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'Some man'},
#   {'prefix': 'Some girl that should praise the Lutherans attacks',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'Some girl'},
#   {'prefix': "Most guests that were hugging Daniel hadn't attacked",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Most guests'},
#   {'prefix': "These guests who won't boycott that association hurt",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'These guests'},
#   {'prefix': 'These children who wore that shawl are finding',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'These children'},
#   {'prefix': "Banks that can't resemble that drawing have disliked",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Banks that'},
#   {'prefix': 'Every bird that might distract Todd has disgusted',
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Every bird'},
#   {'prefix': "Every cup that hasn't bothered Deanna hadn't upset",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Every cup'},
#   {'prefix': 'Every government that remembers Sheila has talked about',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Every government'},
#   {'prefix': 'These waiters that flee from Teresa can visit',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'These waiters'},
#   {'prefix': 'Most patients who notice Amy have complained about',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Most patients'},
#   {'prefix': "All waiters who aren't scaring Amy haven't referenced",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All waiters'},
#   {'prefix': "That slope that had disturbed James can't scare",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'That slope'},
#   {'prefix': "A man who hasn't annoyed Catherine complains about",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'A man'},
#   {'prefix': "Most hospitals that respect the lake couldn't discuss",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Most hospitals'},
#   {'prefix': "Every association that hadn't disturbed Candice boasts about",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Every association'},
#   {'prefix': 'The girl who would hate Stephen would notice',
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'The girl'},
#   {'prefix': 'All people who confused Kendra had talked about',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All people'},
#   {'prefix': "These carts that haven't confused Daniel have stunned",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'These carts'},
#   {'prefix': 'Some man who describes many art galleries conceals',
#    'good_word': 'himself',
#    'bad_word': 'themselves',
#    'subject': 'Some man'},
#   {'prefix': 'Ladies that had lifted every shoe had disliked',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Ladies that'},
#   {'prefix': 'That girl who climbed down many stairs visits',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'That girl'},
#   {'prefix': "A man who sounds like Pamela wasn't hiring",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'A man'},
#   {'prefix': 'Ladies that skated around a glacier did see',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Ladies that'},
#   {'prefix': "All cups that don't alarm Karla did upset",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All cups'},
#   {'prefix': 'That waitress that sells this cafe boasts about',
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'That waitress'},
#   {'prefix': "A legislature that is hurting Jason hasn't hired",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'A legislature'},
#   {'prefix': "Most people who are criticizing Jason weren't kissing",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Most people'},
#   {'prefix': 'Children who will drop by this mountain liked',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Children who'},
#   {'prefix': "Some girl who hadn't fled from Thomas praises",
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'Some girl'},
#   {'prefix': 'Cashiers that resembled some print have talked to',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Cashiers that'},
#   {'prefix': "Every man who took those unicycles wouldn't see",
#    'good_word': 'himself',
#    'bad_word': 'themselves',
#    'subject': 'Every man'},
#   {'prefix': 'The pork that has irritated Sherry has irritated',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'The pork'},
#   {'prefix': "Those teachers who didn't cure Larry don't help",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Those teachers'},
#   {'prefix': 'All essays that would stun Aaron would confuse',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'All essays'},
#   {'prefix': "Some boy who won't shock Jane wouldn't discover",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'Some boy'},
#   {'prefix': "The girl that shouldn't research some museums loves",
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'The girl'},
#   {'prefix': "Every mushroom that is bothering Keith hadn't annoyed",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Every mushroom'},
#   {'prefix': "Some nose that had disturbed Carlos isn't shocking",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Some nose'},
#   {'prefix': 'All drivers that walked through every mall helped',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'All drivers'},
#   {'prefix': "Most stairs that aren't scaring Rachelle are aggravating",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Most stairs'},
#   {'prefix': "A girl that hadn't cleaned every tomato knows",
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'A girl'},
#   {'prefix': "That guy that shouldn't discuss some lakes leaves",
#    'good_word': 'himself',
#    'bad_word': 'themselves',
#    'subject': 'That guy'},
#   {'prefix': "The actors that shouldn't tour that river watched",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'The actors'},
#   {'prefix': 'These universities that appreciate every actress were worrying',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'These universities'},
#   {'prefix': "That play that wasn't boring Wayne sounds like",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'That play'},
#   {'prefix': "That boy that hadn't attacked Becca had fired",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'That boy'},
#   {'prefix': 'Every lady who should tour a lake praises',
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'Every lady'},
#   {'prefix': "This committee that shouldn't take all shoes discusses",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'This committee'},
#   {'prefix': "Some screen that wasn't aggravating Douglas has bored",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Some screen'},
#   {'prefix': 'This screen that is disgusting Helen did bore',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'This screen'},
#   {'prefix': "Those art galleries that can't hurt Tara distracted",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Those art'},
#   {'prefix': 'Those drivers who were boycotting that association insulted',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Those drivers'},
#   {'prefix': "Every mall that stuns these waitresses hadn't distracted",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'Every mall'},
#   {'prefix': "Those pedestrians that hadn't hated Lori had aggravated",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Those pedestrians'},
#   {'prefix': "Most patients that won't talk to Margaret healed",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Most patients'},
#   {'prefix': "All sketches that have scared Sharon aren't disturbing",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All sketches'},
#   {'prefix': 'This actress that complains about some ladies discusses',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'This actress'},
#   {'prefix': "The tomato that won't embarrass Emily isn't stunning",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'The tomato'},
#   {'prefix': "Some commentary that isn't confusing Melissa would confuse",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Some commentary'},
#   {'prefix': 'Some senators that do alarm Steven boasted about',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Some senators'},
#   {'prefix': 'Some hospital that is working with Theodore admired',
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Some hospital'},
#   {'prefix': "An actress that wasn't shocking Paul didn't criticize",
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'An actress'},
#   {'prefix': 'Some woman that noticed Spain is escaping from',
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'Some woman'},
#   {'prefix': "This candle that disturbs some waiters wouldn't scare",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'This candle'},
#   {'prefix': 'Most men that have astounded Joel had disliked',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Most men'},
#   {'prefix': "This legislature that wouldn't worry Gina talks to",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'This legislature'},
#   {'prefix': "This waitress who cares for James can't investigate",
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'This waitress'},
#   {'prefix': "The guy that hasn't visited Sara boasts about",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'The guy'},
#   {'prefix': 'Cashiers who ascended some ladder should talk to',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Cashiers who'},
#   {'prefix': 'The woman who has worn many hats sees',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'The woman'},
#   {'prefix': "Some customers that complained about Laura haven't hidden",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Some customers'},
#   {'prefix': 'Those guys who had helped Brett had found',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Those guys'},
#   {'prefix': "Many associations that haven't aggravated Carol can't describe",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Many associations'},
#   {'prefix': 'A woman who has known those guys loves',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'A woman'},
#   {'prefix': "Most customers who find that cilantro aren't questioning",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Most customers'},
#   {'prefix': 'Many banks that were alarming this waitress disgusted',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Many banks'},
#   {'prefix': 'All adults that have hugged Edward will stun',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'All adults'},
#   {'prefix': "The museums that hadn't disliked Karen have insulted",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The museums'},
#   {'prefix': "A school that shouldn't work with Carlos criticizes",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'A school'},
#   {'prefix': "All gates that can't confuse Kirsten haven't bored",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All gates'},
#   {'prefix': 'An association that distracted some banks was annoying',
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'An association'},
#   {'prefix': "The actress that cared for Edward isn't concealing",
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'The actress'},
#   {'prefix': 'Most girls that sounded like Wayne were discovering',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Most girls'},
#   {'prefix': "Most students who have distracted Todd couldn't approach",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Most students'},
#   {'prefix': "The doctors who will hire Tracy shouldn't forget",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The doctors'},
#   {'prefix': "Some ladies who shouldn't discover Jason haven't disliked",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Some ladies'},
#   {'prefix': "Some guy that wasn't distracting Paula isn't visiting",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'Some guy'},
#   {'prefix': 'All actresses who could worry Nicole are admiring',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All actresses'},
#   {'prefix': "Some guests that hadn't investigated Samuel haven't questioned",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Some guests'},
#   {'prefix': 'The guests that had found Holly were concealing',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The guests'},
#   {'prefix': 'Every woman that had worn some hats notices',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'Every woman'},
#   {'prefix': "That lamp that wouldn't confuse Julie does bother",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'That lamp'},
#   {'prefix': "That skirt that isn't upsetting Elaine isn't scaring",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'That skirt'},
#   {'prefix': 'Some girl who knows most teenagers boasts about',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'Some girl'},
#   {'prefix': "These mushrooms that do hurt Irene won't distract",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'These mushrooms'},
#   {'prefix': "That guy that had distracted Debra hadn't fired",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'That guy'},
#   {'prefix': "The legislatures that won't talk about Martha remembered",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The legislatures'},
#   {'prefix': "The companies that do know Diane don't know",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The companies'},
#   {'prefix': 'The actresses that are selling some chair helped',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'The actresses'},
#   {'prefix': 'Every screen that would disgust Guy is stunning',
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Every screen'},
#   {'prefix': 'That girl that likes most eyes returned to',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'That girl'},
#   {'prefix': "Some teachers who clean every glass hadn't left",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Some teachers'},
#   {'prefix': 'Many women that fled from Melanie had questioned',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Many women'},
#   {'prefix': 'Those patients that have watched Teresa are hiding',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Those patients'},
#   {'prefix': "This waitress who wasn't attacking these customers observes",
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'This waitress'},
#   {'prefix': "A hill that shouldn't upset Natalie shouldn't annoy",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'A hill'},
#   {'prefix': "A waitress who hadn't discovered many documentaries hired",
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'A waitress'},
#   {'prefix': "This girl who hasn't investigated Douglas had hugged",
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'This girl'},
#   {'prefix': 'These cashiers who will approach Travis are discovering',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'These cashiers'},
#   {'prefix': 'Every unicycle that can astound Bill is confusing',
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'Every unicycle'},
#   {'prefix': 'A waitress that respected every bank escapes from',
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'A waitress'},
#   {'prefix': 'Every woman who flees from Kenneth might attack',
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'Every woman'},
#   {'prefix': "All guests who are visiting Anna didn't see",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All guests'},
#   {'prefix': 'Senators that disturb Harvard University could work with',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Senators that'},
#   {'prefix': "Most cups that could annoy Helen hadn't upset",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Most cups'},
#   {'prefix': "Adults who hadn't hated Regina couldn't talk to",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Adults who'},
#   {'prefix': 'Every lady that did appreciate art returns to',
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'Every lady'},
#   {'prefix': "All guests who aren't observing Margaret hadn't insulted",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All guests'},
#   {'prefix': "Some waitress who hadn't stunned this bank annoyed",
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'Some waitress'},
#   {'prefix': 'Every dancer who cared for some teachers questions',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'Every dancer'},
#   {'prefix': 'The dancer that did examine every documentary describes',
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'The dancer'},
#   {'prefix': 'Some waitress who stunned Lawrence should care for',
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'Some waitress'},
#   {'prefix': 'Every play that had impressed Dawn disagreed with',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Every play'},
#   {'prefix': "Every couch that can't look like drawings stunned",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'Every couch'},
#   {'prefix': "That library that hadn't talked to Teresa praised",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'That library'},
#   {'prefix': "A lady that hasn't irritated many libraries approached",
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'A lady'},
#   {'prefix': 'Those legislatures that did describe David had disliked',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Those legislatures'},
#   {'prefix': "Libraries that aren't hurting Lissa don't talk to",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Libraries that'},
#   {'prefix': "These committees that scare Alexander aren't arguing about",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'These committees'},
#   {'prefix': "Some teachers who hurt Carla haven't complained about",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Some teachers'},
#   {'prefix': "Some adults that can't complain about Jane left",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Some adults'},
#   {'prefix': 'The actors who did approach Sandra had loved',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The actors'},
#   {'prefix': "These women who haven't embarrassed Valerie weren't approaching",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'These women'},
#   {'prefix': "This door that is disturbing Carl hadn't scared",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'This door'},
#   {'prefix': "That spinach that hadn't alarmed Donna was disgusting",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'That spinach'},
#   {'prefix': "A boy who hadn't bothered Nicole had investigated",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'A boy'},
#   {'prefix': 'Those teachers who will arrive at Spain kissed',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Those teachers'},
#   {'prefix': "The men who upset Naomi don't argue about",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The men'},
#   {'prefix': "That broccoli that shouldn't impress Jessica is disturbing",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'That broccoli'},
#   {'prefix': "All students who haven't seen Michael hadn't hidden",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'All students'},
#   {'prefix': 'The guests that might fire Matt have impressed',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'The guests'},
#   {'prefix': "The school that took these blouses wasn't insulting",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'The school'},
#   {'prefix': "That fish that can't break some plates found",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'That fish'},
#   {'prefix': "Some ladies that saw a drawing can't reveal",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Some ladies'},
#   {'prefix': "A woman who didn't describe James has visited",
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'A woman'},
#   {'prefix': 'The cashiers that should praise Lawrence have fired',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'The cashiers'},
#   {'prefix': 'Most women that will astound Michael are discovering',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Most women'},
#   {'prefix': 'Those legislatures that sold this high school forgot',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Those legislatures'},
#   {'prefix': 'Those guys that drop by some hospital loved',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Those guys'},
#   {'prefix': "Some guests who wouldn't discover Jane hadn't healed",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Some guests'},
#   {'prefix': 'This play that has annoyed Daniel has scared',
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'This play'},
#   {'prefix': "Some senators who passed that hospital couldn't conceal",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Some senators'},
#   {'prefix': "The association that has these cars didn't hate",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'The association'},
#   {'prefix': 'Every essay that is hurting Victoria was worrying',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Every essay'},
#   {'prefix': 'Many associations that are arguing about Sonia loved',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Many associations'},
#   {'prefix': "This shawl that will aggravate Dawn can't disgust",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'This shawl'},
#   {'prefix': "This cilantro that wasn't annoying Jason is disturbing",
#    'good_word': 'itself',
#    'bad_word': 'himself',
#    'subject': 'This cilantro'},
#   {'prefix': "Some pictures that resembled this picture can't shock",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Some pictures'},
#   {'prefix': "Some shirt that can't resemble these drawings bored",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'Some shirt'},
#   {'prefix': 'All shoes that could astound Phillip are bothering',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'All shoes'},
#   {'prefix': 'These dancers that complained about Phillip can leave',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'These dancers'},
#   {'prefix': "All guys that lifted a lake won't see",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'All guys'},
#   {'prefix': "This dancer who hadn't known Aaron hadn't appreciated",
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'This dancer'},
#   {'prefix': "The children that won't work with Carla aggravated",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The children'},
#   {'prefix': "All customers who loved this book shouldn't dislike",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'All customers'},
#   {'prefix': 'Cashiers that messed up this dress would love',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Cashiers that'},
#   {'prefix': "The girls that discover Amy aren't listening to",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The girls'},
#   {'prefix': "Most cashiers who can approach Tamara didn't reveal",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Most cashiers'},
#   {'prefix': 'The lady who had healed the man respects',
#    'good_word': 'herself',
#    'bad_word': 'himself',
#    'subject': 'The lady'},
#   {'prefix': "All organizations that hadn't appreciated Laura couldn't respect",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All organizations'},
#   {'prefix': "All pedestrians that aren't kissing Andrea haven't impressed",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All pedestrians'},
#   {'prefix': 'Some committee that hurt the guys had remembered',
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'Some committee'},
#   {'prefix': "The waiters that don't dislike Laurie would kiss",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The waiters'},
#   {'prefix': 'Most waitresses that were helping Jodi might see',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Most waitresses'},
#   {'prefix': 'Many governments that talked to Samuel boasted about',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Many governments'},
#   {'prefix': 'Those women that admire this hill complained about',
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Those women'},
#   {'prefix': 'Those people who stunned Brenda should work with',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Those people'},
#   {'prefix': "That essay that shouldn't disturb Carmen disagreed with",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'That essay'},
#   {'prefix': 'That association that is confusing Alicia could fire',
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'That association'},
#   {'prefix': "Those drivers who hadn't left Kimberley wouldn't forget",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Those drivers'},
#   {'prefix': "That legislature that had these casseroles hadn't insulted",
#    'good_word': 'itself',
#    'bad_word': 'themselves',
#    'subject': 'That legislature'},
#   {'prefix': "These associations that confuse Timothy aren't listening to",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'These associations'},
#   {'prefix': "A man that has kissed Karen shouldn't fire",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'A man'},
#   {'prefix': 'Some actress that is visiting those men attacks',
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'Some actress'},
#   {'prefix': "The dancer who isn't ascending that slope insults",
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'The dancer'},
#   {'prefix': 'Every boy that cares for Anne is hiding',
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'Every boy'},
#   {'prefix': "Many organizations that won't worry William had confused",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Many organizations'},
#   {'prefix': 'All reports that have bored Jerry have disgusted',
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'All reports'},
#   {'prefix': "Some guy that didn't work with Kirsten hugs",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'Some guy'},
#   {'prefix': "Those carts that aren't impressing Noah hadn't confused",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Those carts'},
#   {'prefix': "Those convertibles that don't scare Kevin are upsetting",
#    'good_word': 'themselves',
#    'bad_word': 'himself',
#    'subject': 'Those convertibles'},
#   {'prefix': "Those women who aren't going to Spain respected",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'Those women'},
#   {'prefix': 'A lot of libraries that shock Nina hires',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'A lot'},
#   {'prefix': "That association that hadn't worked with Sonia insults",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'That association'},
#   {'prefix': "A woman that hadn't taken those photographs disliked",
#    'good_word': 'herself',
#    'bad_word': 'themselves',
#    'subject': 'A woman'},
#   {'prefix': 'All doctors that were aggravating Vanessa escaped from',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All doctors'},
#   {'prefix': 'Some man that does lift some scarf observes',
#    'good_word': 'himself',
#    'bad_word': 'itself',
#    'subject': 'Some man'},
#   {'prefix': "The people who have worried Lisa weren't firing",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'The people'},
#   {'prefix': 'Some waitresses that impress Catherine are listening to',
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Some waitresses'},
#   {'prefix': "That steak that hasn't disturbed Elaine did astound",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'That steak'},
#   {'prefix': "The children that found that jacket weren't firing",
#    'good_word': 'themselves',
#    'bad_word': 'itself',
#    'subject': 'The children'},
#   {'prefix': "All mushrooms that haven't disturbed Wendy hadn't disgusted",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'All mushrooms'},
#   {'prefix': 'This lady who looks like the picture approached',
#    'good_word': 'herself',
#    'bad_word': 'itself',
#    'subject': 'This lady'},
#   {'prefix': "Every fish that isn't hurting Carmen won't find",
#    'good_word': 'itself',
#    'bad_word': 'herself',
#    'subject': 'Every fish'},
#   {'prefix': "Those children who aren't impressing Valerie could reference",
#    'good_word': 'themselves',
#    'bad_word': 'herself',
#    'subject': 'Those children'},
#   {'prefix': "Some boy who hadn't hated Melinda escaped from",
#    'good_word': 'himself',
#    'bad_word': 'herself',
#    'subject': 'Some boy'}])
